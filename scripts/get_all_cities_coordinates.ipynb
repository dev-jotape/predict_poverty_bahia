# %%
import geopandas as gpd

# %%
shape_br = gpd.read_file('../input/shapes/BR/BR_Localidades_2010_v1.shp');
shape_br = shape_br[(shape_br['NM_UF'] == 'BAHIA') & (shape_br['NM_CATEGOR'] == 'CIDADE')][['CD_GEOCODM', 'NM_MUNICIP', 'NM_UF', 'LONG', 'LAT']]
shape_br
# Out:
#       CD_GEOCODM            NM_MUNICIP  NM_UF       LONG        LAT
# 9250     2900108                ABAÍRA  BAHIA -41.661608 -13.253532
# 9254     2900207                 ABARÉ  BAHIA -39.116588  -8.723418
# 9263     2900306             ACAJUTIBA  BAHIA -38.018286 -11.662613
# 9265     2900355              ADUSTINA  BAHIA -38.115506 -10.529572
# 9269     2900405             ÁGUA FRIA  BAHIA -38.768078 -11.872931
# ...          ...                   ...    ...        ...        ...
# 11931    2933307  VITÓRIA DA CONQUISTA  BAHIA -40.839810 -14.848005
# 11961    2933406                WAGNER  BAHIA -41.169627 -12.284251
# 11964    2933455             WANDERLEY  BAHIA -43.888930 -12.120150
# 11969    2933505   WENCESLAU GUIMARÃES  BAHIA -39.479671 -13.688588
# 11978    2933604           XIQUE-XIQUE  BAHIA -42.725508 -10.824974
#
# [417 rows x 5 columns]

# %%
shape_br.to_csv('../model/city_center_coordinates.csv', index=False)
